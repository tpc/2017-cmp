# %%
import matplotlib.pyplot as plt

N = 100
a = 1624
c = 1012
m = 11 #2**31-1 #4245035300
x = 1
results = []

for i in range(N):      
    x = (a*x+c)%m
    results.append(x)
plt.plot(results,"o")
plt.show()

plt.hist(results)
plt.show()

# %%
import matplotlib.pyplot as plt

N = 100
a = 2
c = 0
m = 11 #2**31-1 #4245035300
x = 1
results = []

for i in range(N):      
    x = (a*x+c)%m
    results.append(x)
plt.plot(results,"o")
plt.show()

plt.hist(results)
plt.show()

# %%
import matplotlib.pyplot as plt

N = 10000
a = 2
c = 0
m = 11 #4245035300
x = 1
results = []

for i in range(N):
    x = (a*x+c)%m
    print(x)
    results.append(x-6)
    #if x < 6:
    #    #print(x)
    #    results.append(x-1)
    #elif x > 5:
    #    x = -10 + x
    #    #print(x)
    #    results.append(x)
plt.plot(results,"o")
plt.show()

plt.hist(results)
plt.show()
# Out:
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# 10
# 9
# 7
# 3
# 6
# 1
# 2
# 4
# 8
# 5
# ...

# %%
import matplotlib.pyplot as plt

N = 100
a = 1624
c = 1012
m = 11 #2**31-1 #4245035300
x = 1
results = []

for i in range(N):      
    x = (a*x+c)%m
    results.append(x)
plt.plot(results,"o")
plt.show()

plt.hist(results)
plt.show()

# %%
import random

print(random.randint(1, 6))
print(random.randint(1, 6))

double_6s_counter = 0
N = 1000000

for i in range(N):
    x_0 = random.randint(1, 6)
    x_1 = random.randint(1, 6)
    if x_0 == 6 and x_1 == 6:
        double_6s_counter += 1

print(double_6s_counter)
print(double_6s_counter/N)
# Out:
# 1
# 2
# 27768
# 0.027768

# %%
import vpython
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=[18, 12])
# init
L1 = 101
L2 = 101
N = 10000

position = np.empty([N,2])
position[0,0] = int(L1/2)
position[0,1] = int(L2/2)
direction = np.array([[0,1],[0,-1],[1,0],[-1,0]])

# random walk
for i in range(1,N):
    position1 = [-1,-1]
    
    while min(position1)<0 or position1[0] >L1 or position1[1] >L2:
        move = np.random.randint(len(direction))
        position1 = position[i-1,:] + direction[move]
        
    position[i,:] = position1
plt.xlim(0,101)
plt.ylim(0,101)
plt.title('Brownian motion')
plt.scatter(position[:,0], position[:,1], c=range(N), s=5)
plt.text(position[0,0], position[0,1], 'start', fontsize=16)
plt.text(position[-1,0], position[-1,1], 'end', fontsize=16)

plt.colorbar()
plt.show()

# %%
## Decay process
import numpy as np
import matplotlib.pyplot as plt


# Initial parameters
NTl = 1000
NPb = 0
tau = 3.053*60
dt = 1 
p = 1 - 2**(-dt/tau)
tmax = 1000

t_points = np.arange(0.0, tmax, dt)
Tl = []
Pb = []

for t in t_points:
    Tl.append(NTl)
    Pb.append(NPb)
    
    # Calculate the decayed atoms
    decay = 0
    for i in range(NTl):
        if np.random.random()<p:
            decay += 1
    NTl -= decay
    NPb += decay

plt.plot(t_points, Tl, label='Tl')
plt.plot(t_points, Pb, label='Pb')
plt.xlabel("Time")
plt.ylabel("Number of atoms")
plt.legend()
plt.show()

# %%
# To generate the exponential distribution from uniform distribution
import numpy as np
import matplotlib.pyplot as plt

tau = 3.053*60
t = np.linspace(0,1000,100)
#y = 1000*(1-2**(-t/tau)*np.log(2)/tau)
y = (2**(-t/tau)*np.log(2)/tau)
Tl = []
Pb = []
NTl = 1000
NPb = 0

plt.plot(t,y)
plt.xlim(0,1000)
plt.show()

N = 10000
mu = np.log(2)/tau
x = []
for i in range(N):
    Tl.append(NTl)
    Pb.append(NPb)
    
    z0 = np.random.random()
    x.append(-np.log(1-z0)/mu)
    
plt.hist(x,100, normed=1)
plt.xlim(0,1000)
plt.show()
# Out:
# /Users/user/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# %gui tk

from vpython import *
box()
sphere (pos=vector(-1,0,0),radius=0.25, color=color.red)
sphere (pos=vector(1,1,0),radius=0.15, color=color.orange)
arrow(pos=vector (0,0,0), axis=vector(0,1,0), color=color.yellow)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
# %gui tk

from vpython import *
import numpy as np
from random import uniform

T = 2
mu = 0.1
sigma = 0.01
S0 = 20
dt = 0.01
N = round(T/dt)
t = np.linspace(0, T, N)
W = np.random.standard_normal(size = N) 
W = np.cumsum(W)*np.sqrt(dt) ### standard brownian motion ###
X = (mu-0.5*sigma**2)*t + sigma*W 
S = S0*np.exp(X)

maxv = 1.0

ball = sphere(pos=vector(-5,0,0), radius=0.5, color=color.cyan)
ball.trail = curve(color=ball.color)
wallR = box(pos=vector(6,0,0), size=vector(0.2,12,12), color=color.green)
ball.velocity = vector(25,5,10)
#ball.velocity=maxv*vector(uniform(-1,1),uniform(-1,1),uniform(-1,1))
deltat = 0.005
t = 0
#a_length = len(S)
while 1==1:
    rate(100)
    if ball.pos.x > wallR.pos.x:
        ball.velocity.x = -ball.velocity.x
    #ball.pos = vector(ball.pos.x + ball.velocity*deltat, ball.pos.y + ball.velocity*deltat*S[a_length - 1], ball.pos.z + ball.velocity*deltat*S[a_length - 1])
    ball.pos = ball.pos + ball.velocity*deltat
    #ball.pos.x = ball.pos.x + ball.velocity.x*deltat
    #ball.pos.y = ball.pos.y*deltat*S[a_length - 1] + ball.velocity.y*deltat*S[a_length - 1]
    #ball.pos.z = ball.pos.z + ball.velocity.z*deltat
    #a_length = a_length - 1
    ball.trail.append(pos=ball.pos)
    t = t + deltat
scene.autoscale = False
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-03c21a09ae10> in <module>
#      28 #a_length = len(S)
#      29 while 1==1:
# ---> 30     rate(100)
#      31     if ball.pos.x > wallR.pos.x:
#      32         ball.velocity.x = -ball.velocity.x
#
# ~/miniconda3/lib/python3.6/site-packages/vpython/vpython.py in __call__(self, N)
#     214         self.rval = N
#     215         if self.rval < 1: raise ValueError("rate value must be greater than or equal to 1")
# --> 216         super(_RateKeeper2, self).__call__(self.rval) ## calls __call__ in rate_control.py
#     217
#     218 if sys.version > '3':
#
# ~/miniconda3/lib/python3.6/site-packages/vpython/rate_control.py in __call__(self, maxRate)
#     205             dt = self.lastSleep + self.calls*(self.userTime + self.callTime + self.delay) + \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

T = 2
mu = 0.1
sigma = 0.01
S0 = 20
dt = 0.01
N = round(T/dt)
t = np.linspace(0, T, N)
W = np.random.standard_normal(size = N) 
W = np.cumsum(W)*np.sqrt(dt) ### standard brownian motion ###
X = (mu-0.5*sigma**2)*t + sigma*W 
S = S0*np.exp(X) ### geometric brownian motion ###
print(S)
plt.figure(figsize=[45, 45])
plt.xticks(size=72, weight=500)
plt.yticks(size=72, weight=500)
plt.plot(t, S)
plt.show()
# Out:
# [20.00136506 20.01333694 20.05104074 20.05414792 20.06672079 20.1118971
#  20.10695625 20.13995357 20.14906967 20.1829538  20.23095169 20.28274145
#  20.32458514 20.36634969 20.40054165 20.4438446  20.47135072 20.52020949
#  20.5741345  20.54640208 20.5783149  20.60163012 20.59961903 20.61342181
#  20.66946829 20.68238163 20.70892246 20.71771863 20.71959254 20.72804358
#  20.75446986 20.80365589 20.80767155 20.82706345 20.83406643 20.88988656
#  20.90278171 20.92929185 20.95889484 20.98275798 20.96521316 20.96978064
#  20.99386806 20.99514935 21.02067336 21.05833085 21.04459687 21.04879391
#  21.064543   21.12852528 21.18228634 21.2358223  21.28599148 21.2887853
#  21.29955784 21.34013041 21.34971085 21.37372401 21.37820958 21.35301414
#  21.37303729 21.35633704 21.40063409 21.42448657 21.44768538 21.45059116
#  21.4886161  21.53110541 21.53432364 21.52845762 21.54850102 21.59325272
#  21.61233796 21.61831924 21.60070513 21.62793746 21.64912773 21.67200798
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
#Spanish
#Funcion que genera la caminata aleatoria de UNA particula
#@param steps es el numero de pasos que debe dar cada particula
#@param step es el valor del desplazamiento en cada paso
def path_generator(steps, step):
    path = np.empty((3, steps))
    for i in range(1, steps):
        x_ran, y_ran, z_ran = np.random.rand(3)
        sgnX = (x_ran - 0.5)/abs(x_ran - 0.5)
        sgnY = (y_ran - 0.5)/abs(y_ran - 0.5)
        sgnZ = (z_ran - 0.5)/abs(z_ran - 0.5)
        dis = np.array([step*sgnX, step*sgnY, step*sgnZ])
        path[:, i] = path[:, i - 1] + dis

    return path

fig = plt.figure()
ax = p3.Axes3D(fig)
#arreglo con la posicion de cada particula              
particles = [path_generator(1000, 1) for i in range(100)]
#trayectoria de cada particula
trajectories = [ax.plot(particle[0, 0:1], particle[1, 0:1], particle[2, 0:1])[0] for particle in particles]
                   
def animate(i):
    global particles, trajectories
    for trajectory, particle in zip(trajectories, particles):
        #coordenadas x,y de la particula hasta el tiempo i
        trajectory.set_data(particle[0:2, :i])
        #coordenada z de la particula hasta el tiempo i
        trajectory.set_3d_properties(particle[2, :i])  
    
    return trajectories
                 
ax.set_xlim3d([-100, 100])
ax.set_ylim3d([-100, 100])
ax.set_zlim3d([-100, 100])


animacion = animation.FuncAnimation(fig, animate, 1000, interval=50, blit=False)
FFwriter = animation.FFMpegWriter()
plt.show()

# %%
# %gui tk

from vpython import *

side=4.0
ballradius=0.4
thk=0.3
s2 = 2*side - thk 
s3 = 2*side + thk
maxpos=side-thk/2-ballradius 
maxv=2.0

#create a ball and set its velocity
ball = sphere (color = color.green, radius = ballradius) 
ball.velocity = vector (-1.5, -2.3, +2.7)

#create 5 joining walls
wallR = box (pos=vector( side, 0, 0), size=vector(thk, s2, s3), color = color.red) 
wallL = box (pos=vector(-side, 0, 0), size=vector(thk,s2, s3), color = color.red) 
wallB = box (pos=vector(0, -side, 0), size=vector(s3,thk,s3), color = color.blue) 
wallT = box (pos=vector(0, side, 0), size=vector(s3,thk,s3), color = color.blue) 
wallBK = box(pos=vector(0, 0, -side), size=vector(s2,s2, thk), color = vector(0.7,0.7,0.7)) 

#set the timestep between motion
timestep = 0.05

while (1==1):
    rate(100)
    #code within this while loop is repeated up to 100 times per second
    #until the program is stopped
    
    ball.pos = ball.pos + ball.velocity*timestep #moves ball

    #check for collisions with the walls
    #right wall
    if ball.pos.x > maxpos: 
        ball.velocity.x = -ball.velocity.x #reflect velocity
        ball.pos.x=2*maxpos-ball.pos.x #reflect position
    #left wall
    if ball.pos.x < -maxpos: 
        ball.velocity.x = -ball.velocity.x 
        ball.pos.x=-2*maxpos-ball.pos.x
    # roof
    if ball.pos.y > maxpos: 
        ball.velocity.y = -ball.velocity.y 
        ball.pos.y=2*maxpos-ball.pos.y
    #floor
    if ball.pos.y < -maxpos: 
        ball.velocity.y = -ball.velocity.y 
        ball.pos.y=-2*maxpos-ball.pos.y
    #back wall
    if ball.pos.z > maxpos: 
        ball.velocity.z = -ball.velocity.z 
        ball.pos.z=2*maxpos-ball.pos.z
    #front wall
    if ball.pos.z < -maxpos: 
        ball.velocity.z = -ball.velocity.z 
        ball.pos.z=-2*maxpos-ball.pos.z

# %%
import numpy as np
from vpython import *
import matplotlib.pyplot as plt

L1 = 101
L2 = 101
moves = 10000
def game():
    posx = 50
    posy = 50

    xmoves = []
    ymoves = []
    for i in range(moves):
        move = np.random.randint(1,5)
        if move == 1:
            if posx >= L1:
                continue
            posx += 1
        elif move == 2:
            if posx <= 0:
                continue
            posx -= 1
        elif move == 3:
            if posy >= L2:
                continue
            posy += 1
        elif move == 4:
            if posy <= 0:
                continue
            posy -= 1
        xmoves.append(posx)
        ymoves.append(posy)
    background = canvas(title='Examples of Brownian Motion',
         width=700, height=700,
         center=vector(50,50,0), background=color.red)
    s = sphere(pos=vector(50,50,0),radius=5,color=color.blue, make_trail = True)

    for i in range(moves):
        rate(190)
        x = xmoves[i]
        y = ymoves[i]
        s.pos = vector(x,y,0)
    plt.plot(xmoves,ymoves, '-')
    plt.show()

game()
# Out:
# <div id="glowscript" class="glowscript"></div>
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-41645a74d342> in <module>
#      45     plt.show()
#      46
# ---> 47 game()
#
# <ipython-input-1-41645a74d342> in game()
#      38
#      39     for i in range(moves):
# ---> 40         rate(190)
#      41         x = xmoves[i]
#      42         y = ymoves[i]
#
# ~/miniconda3/lib/python3.6/site-packages/vpython/vpython.py in __call__(self, N)
#     214         self.rval = N
#     215         if self.rval < 1: raise ValueError("rate value must be greater than or equal to 1")
# --> 216         super(_RateKeeper2, self).__call__(self.rval) ## calls __call__ in rate_control.py
#     217
#     218 if sys.version > '3':
#
# ~/miniconda3/lib/python3.6/site-packages/vpython/rate_control.py in __call__(self, maxRate)
# ...

# %%
def f2(x): #complex function with 2 minimum
    return x[0]**2/2 + x[1]**2/3 - x[0]*x[1]/4 + 3* np.exp(-(x[0]-1)**2)

def grid_search(N):
    x_min, x_max = -4, 4
    y_min, y_max = -4, 4                   
    minf = f2([x_min,y_min])
        
    #---to complete-----#

    nx = np.linspace(x_min,x_max, N)
    ny = np.linspace(y_min,y_max, N)

    x,y = np.meshgrid(nx,ny)
    z = f2([x, y])
    #levels = np.arange(np.min(z), np.max(z), 0.3)
    #---to complete-----#
    return np.min(z)

#grid_search(1000)

def a_rand_gen(x_min, x_max, y_min, y_max):
    x0 = x_min+np.random.random()*(x_max-x_min)
    y0 = y_min+np.random.random()*(y_max-y_min)
    return x0, y0

# Random search
def random_search(N):
    x_min, x_max = -4, 4
    y_min, y_max = -4, 4                   
    minf = f2([x_min,y_min])
    #---to complete-----#

    z = []
    for i in range(N):
        x0 = x_min+np.random.random()*(x_max-x_min)
        y0 = y_min+np.random.random()*(y_max-y_min)
        z.append(f2([x0, y0]))
    #---to complete-----#            
    return np.min(z)

random_search(100000)
# Out:
# 0.38797767683044426

# %%
from scipy.optimize import minimize
import numpy as np

#[x0, y0] = init(x_min, x_max, y_min, y_max)

def f2(x): #complex function with 2 minimum
    return x[0]**2/2 + x[1]**2/3 - x[0]*x[1]/4 + 3* np.exp(-(x[0]-1)**2)

# Random search
def random_search_Mixed_Strategy(N):
    x_min, x_max = -4, 4
    y_min, y_max = -4, 4                   
    minf = f2([x_min,y_min])
    #---to complete-----#

    z = []
    for i in range(N):
        x0 = x_min+np.random.random()*(x_max-x_min)
        y0 = y_min+np.random.random()*(y_max-y_min)
        res = minimize(f2, [x0,y0], method='nelder-mead', tol=1e-4, options={'disp': False})
        z.append(res.fun)
    #---to complete-----#            
    return np.min(z)

random_search_Mixed_Strategy(100)
# Out:
# 0.3878588685171904

# %%
import numpy as np
from scipy.optimize import minimize

def f(x, y):
    return (x**2 / 2) + (y**2 / 3) - (x*y/4)

def init(x_min, x_max, y_min, y_max):
    x0 = x_min+np.random.random()*(x_max-x_min)
    y0 = y_min+np.random.random()*(y_max-y_min)
    return [x0, y0]

x_min, x_max = -4, 4
y_min, y_max = -4, 4

[x0, y0] = init(x_min, x_max, y_min, y_max)
#results = minimize(f, [x0, y0], method='nelder-mead', tol=1e-4, options={'disp': True})


def grid_search(N):
    x_min, x_max = -4, 4
    y_min, y_max = -4, 4                   
        
    #---to complete-----#

    nx = np.linspace(x_min,x_max, N)
    ny = np.linspace(y_min,y_max, N)

    x,y = np.meshgrid(nx,ny)
    z = f(x, y)
    #levels = np.arange(np.min(z), np.max(z), 0.3)
    #---to complete-----#
    return np.min(z)

grid_search(1000)
# Out:
# 9.352028037379635e-06

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x_min, x_max = -2, 2                          # range of x
y_min, y_max = -2, 2                          # range of x

def f2(x,y):
    return 1/2*x**2 + 1/4*y**2

nx = np.linspace(x_min,x_max,100)
ny = np.linspace(y_min,y_max,100)

x,y = np.meshgrid(nx,ny)

z = f2(x, y)
print("using np.min, minimum is: ", np.min(z))

def random_search(N):
    x_min, x_max = -4, 4
    y_min, y_max = -4, 4                   
    minf = f2(x_min,y_min)
    #---to complete-----#

    z = []
    for i in range(N):
        x0 = x_min+np.random.random()*(x_max-x_min)
        y0 = y_min+np.random.random()*(y_max-y_min)
        z.append(f2(x0, y0))
    #---to complete-----#            
    return np.min(z)

print("using random search, minimum is: ", random_search(10000))

cur_x, cur_y = 6, 7 # The algorithm starts at x=6
gamma = 0.01 # step size multiplier
precision = 0.00001
previous_step_size = 1 
max_iters = 10000 # maximum number of iterations
iters = 0 #iteration counter

df = lambda x, y: 1/2*x**2 + 1/4*y**2
cur_z = df(cur_x, cur_y)

while (previous_step_size > precision) & (iters < max_iters):
    prev_z = df(prev_x, prev_y)
    prev_x = cur_x
    prev_y = cur_y
    cur_z -= gamma * df(prev_x, prev_y)
    previous_step_size = abs(cur_z - prev_z)
    iters+=1

print("using gradient descent, minimum is: ", np.min(z))

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x,y,z, cmap='summer', alpha=0.8)
cset = ax.contour(x,y,z, zdir='z', offset=0)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f')

plt.show()
# Out:
# using np.min, minimum is:  0.0003060912151821215
# using random search, minimum is:  0.00018862176605256018
# using gradient descent, minimum is:  0.0003060912151821215
