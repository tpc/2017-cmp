# %%
import pandas as pd

tables = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171008&end=20181008")
print(tables[0])
# Out:
#              Date    Open*     High      Low  Close**      Volume  \
# 0    Oct 07, 2018  6590.68  6641.49  6557.04  6602.95  3306630000
# 1    Oct 06, 2018  6622.45  6628.54  6577.80  6588.31  3259740000
# 2    Oct 05, 2018  6574.15  6623.62  6557.41  6622.48  3671500000
# 3    Oct 04, 2018  6497.91  6603.31  6497.91  6576.69  3838410000
# 4    Oct 03, 2018  6553.86  6571.46  6454.03  6502.59  3887310000
# 5    Oct 02, 2018  6593.24  6611.84  6537.90  6556.10  3979260000
# 6    Oct 01, 2018  6619.85  6653.30  6549.08  6589.62  4000970000
# 7    Sep 30, 2018  6604.71  6643.78  6566.54  6625.56  4002280000
# 8    Sep 29, 2018  6643.10  6643.10  6511.65  6601.96  4363690000
# 9    Sep 28, 2018  6678.75  6785.03  6598.32  6644.13  5014430000
# 10   Sep 27, 2018  6495.29  6712.10  6464.95  6676.75  4606810000
# 11   Sep 26, 2018  6452.79  6585.91  6397.89  6495.00  4437300000
# 12   Sep 25, 2018  6603.64  6603.64  6381.86  6446.47  4726180000
# ...

# %%
import pandas as pd

table_with_dates_converted_to_time_objects, = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171008&end=20181008", header=0, parse_dates=["Date"])
print(table_with_dates_converted_to_time_objects)
table_with_dates_converted_to_time_objects.describe()
table_with_dates_converted_to_time_objects['Open*'].count()

import matplotlib.pyplot as plt
import matplotlib.image as image 

image.rcParams["figure.figsize"] = [45, 45] 
plt.plot(table_with_dates_converted_to_time_objects['Date'], table_with_dates_converted_to_time_objects['Open*'], 'r', linewidth=12)
plt.title('12 months Bitcoin opening price', size=144, weight=1000)
plt.xlabel('Oct. 8, 2017 to Oct. 7, 2018 ', size=144, weight=1000)
plt.xticks(size=72, weight=500)
plt.ylabel('Bitcoin Opening Price', size=144, weight=1000)
plt.yticks(size=72, weight=500)

plt.show()
# Out:
#           Date    Open*     High      Low  Close**      Volume    Market Cap
# 0   2018-10-07  6590.68  6641.49  6557.04  6602.95  3306630000  114074648410
# 1   2018-10-06  6622.45  6628.54  6577.80  6588.31  3259740000  114614282649
# 2   2018-10-05  6574.15  6623.62  6557.41  6622.48  3671500000  113767335788
# 3   2018-10-04  6497.91  6603.31  6497.91  6576.69  3838410000  112435991226
# 4   2018-10-03  6553.86  6571.46  6454.03  6502.59  3887310000  113392236466
# 5   2018-10-02  6593.24  6611.84  6537.90  6556.10  3979260000  114062551875
# 6   2018-10-01  6619.85  6653.30  6549.08  6589.62  4000970000  114509724600
# 7   2018-09-30  6604.71  6643.78  6566.54  6625.56  4002280000  114234369232
# 8   2018-09-29  6643.10  6643.10  6511.65  6601.96  4363690000  114885697090
# 9   2018-09-28  6678.75  6785.03  6598.32  6644.13  5014430000  115489513453
# 10  2018-09-27  6495.29  6712.10  6464.95  6676.75  4606810000  112305283440
# ...

# %%
import pandas as pd

table = pd.read_csv("/Users/user/Downloads/multiTimeline.csv")
print(table)

table_parsed = pd.read_csv("/Users/user/Downloads/multiTimeline.csv", header=1, parse_dates=["Week"])
print(table_parsed["Week"].count())

import matplotlib.pyplot as plt
import matplotlib.image as image 

image.rcParams["figure.figsize"] = [45, 45] 
plt.plot(table_parsed['Week'], table_parsed['bitcoin: (Worldwide)'], 'r', linewidth=12)
plt.title('52 weeks Bitcoin searches', size=144, weight=1000)
plt.xlabel('Oct. 8, 2017 to Oct. 7, 2018 ', size=144, weight=1000)
plt.xticks(size=72, weight=500)
plt.ylabel('Bitcoin search popularity on Google', size=144, weight=1000)
plt.yticks(size=72, weight=500)
plt.show()
# Out:
#            Category: All categories
# Week           bitcoin: (Worldwide)
# 2017-10-08                       19
# 2017-10-15                       20
# 2017-10-22                       20
# 2017-10-29                       28
# 2017-11-05                       29
# 2017-11-12                       31
# 2017-11-19                       28
# 2017-11-26                       66
# 2017-12-03                       91
# 2017-12-10                       85
# 2017-12-17                      100
# 2017-12-24                       64
# 2017-12-31                       47
# 2018-01-07                       46
# 2018-01-14                       58
# 2018-01-21                       38
# 2018-01-28                       40
# 2018-02-04                       47
# 2018-02-11                       27
# 2018-02-18                       24
# 2018-02-25                       19
# 2018-03-04                       19
# 2018-03-11                       19
# 2018-03-18                       18
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image 


table_with_dates_converted_to_time_objects, = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171008&end=20181008", header=0, parse_dates=["Date"])
table_with_dates_converted_to_time_objects.describe()
table_with_dates_converted_to_time_objects['Open*'].count()

table_parsed = pd.read_csv("/Users/user/Downloads/multiTimeline.csv", header=1, parse_dates=["Week"])

image.rcParams["figure.figsize"] = [45, 45] 
plt.subplot(211)
plt.plot(table_with_dates_converted_to_time_objects['Date'], table_with_dates_converted_to_time_objects['Open*'], 'r', linewidth=12)
plt.title('12 months Bitcoin opening price', size=144, weight=1000)
#plt.xlabel('Oct. 8, 2017 to Oct. 7, 2018 ', size=144, weight=1000)
plt.xticks(size=72, weight=500)
plt.ylabel('Bitcoin Opening Price', size=144, weight=1000)
plt.yticks(size=72, weight=500)

plt.subplot(212)
plt.plot(table_parsed['Week'], table_parsed['bitcoin: (Worldwide)'], 'r', linewidth=12)
plt.title('52 weeks Bitcoin searches', size=144, weight=1000)
plt.xlabel('Oct. 8, 2017 to Oct. 7, 2018 ', size=144, weight=1000)
plt.xticks(size=72, weight=500)
plt.ylabel('search popularity', size=144, weight=1000)
plt.yticks(size=72, weight=500)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image 


table_with_dates_converted_to_time_objects, = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171008&end=20181008", header=0, parse_dates=["Date"])
table_with_dates_converted_to_time_objects.describe()
table_with_dates_converted_to_time_objects['Open*'].count()

table_parsed = pd.read_csv("/Users/user/Downloads/multiTimeline.csv", header=1, parse_dates=["Week"])

image.rcParams["figure.figsize"] = [45, 45] 
plt.plot(table_with_dates_converted_to_time_objects['Date'], table_with_dates_converted_to_time_objects['Open*'], 'r', table_parsed['Week'], table_parsed['bitcoin: (Worldwide)'] * 200, 'g', linewidth=12)
plt.title('Bitcoin price vs search popularity', size=144, weight=1000)
plt.xlabel('Oct. 8, 2017 to Oct. 7, 2018 ', size=144, weight=1000)
plt.xticks(size=72, weight=500)
plt.ylabel('Bitcoin Opening Price', size=144, weight=1000)
plt.yticks(size=72, weight=500)
plt.legend(["Price", "Popularity"], fontsize=72)

plt.show()

# %%
from scipy import integrate
import numpy as np

f = lambda x: 1/np.sqrt(2*np.pi)*np.exp(-x**2/2) 

a_tuple = integrate.quad(f, -10, 10)
print(a_tuple[0])
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi
from scipy.interpolate import *
from random import random
import pandas as pd

table_with_dates_converted_to_time_objects, = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20171008&end=20181008", header=0, parse_dates=["Date"])
table_with_dates_converted_to_time_objects.describe()
x_list = table_with_dates_converted_to_time_objects['Date']
y_list = table_with_dates_converted_to_time_objects['Open*']
order = 10

fit = np.polyfit(x_list, y_list, order, full=True)
y_p = np.polyval(fit[0], x_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-32efe23a9bd3> in <module>
#      12 order = 10
#      13
# ---> 14 fit = np.polyfit(x_list, y_list, order, full=True)
#      15 y_p = np.polyval(fit[0], x_list)
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     539     """
#     540     order = int(deg) + 1
# --> 541     x = NX.asarray(x) + 0.0
#     542     y = NX.asarray(y) + 0.0
#     543
#
# TypeError: ufunc add cannot use operands with types dtype('<M8[ns]') and dtype('float64')
